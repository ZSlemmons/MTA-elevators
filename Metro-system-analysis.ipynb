# %%
#This notebook is for the purpose of comparing the accessability of various metro systems

# %% [markdown]
# ## The MTA

# %%
import pandas as pd
import numpy as np

#read in MTA data source
mta_data = pd.read_csv('/Users/zoeslemmons/Desktop/MTA-elevators/systems_data/MTA_Subway_Stations.csv')
mta_data.head()
# Out:
#   GTFS Stop ID  Station ID  Complex ID Division              Line  \
# 0          127         317         611      IRT    Broadway - 7Av
# 1          S17         515         515      SIR     Staten Island
# 2          S01         139         627      BMT  Franklin Shuttle
# 3          254         349         349      IRT       Eastern Pky
# 4          M01         108         108      BMT         Myrtle Av
#
#                         Stop Name Borough    CBD Daytime Routes Structure  \
# 0                  Times Sq-42 St       M   True          1 2 3    Subway
# 1                        Annadale      SI  False            SIR  Open Cut
# 2                     Franklin Av      Bk  False              S  Elevated
# 3                       Junius St      Bk  False              3  Elevated
# 4  Middle Village-Metropolitan Av       Q  False              M  Elevated
#
#    GTFS Latitude  GTFS Longitude North Direction Label South Direction Label  \
# 0      40.755290      -73.987495                Uptown              Downtown
# 1      40.540460      -74.178217                 Ferry           South Shore
# 2      40.680596      -73.955827             Last Stop         Prospect Park
# 3      40.663515      -73.902447             Manhattan              New Lots
# 4      40.711396      -73.889601               Inbound             Last Stop
#
#    ADA  ADA Northbound  ADA Southbound ADA Notes                  Georeference
# 0    1               1               1       NaN   POINT (-73.987495 40.75529)
# 1    0               0               0       NaN   POINT (-74.178217 40.54046)
# 2    1               1               1       NaN  POINT (-73.955827 40.680596)
# 3    0               0               0       NaN  POINT (-73.902447 40.663515)
# 4    1               1               1       NaN  POINT (-73.889601 40.711396)

# %%
#Checking that the data includes all the stations. There should be 472 not including the Staten Island Railroad
mta_data['Division'].value_counts()
# Out:
# Division
# IRT    178
# IND    155
# BMT    142
# SIR     21
# Name: count, dtype: int64

# %%
#Hmmm...that adds up to 475. Where are the 3 extra coming from. Let's look at how many unique station IDs there are
ids = mta_data['Station ID'].unique()

# %%
#subtract the SIR stations
len(ids) - 21
# Out:
# 472

# %%
#Bingo, ok so there are repeats somewhere, but at least I know we have all the stations
#I can find the duplicates

mta_data['Station ID'].value_counts()
# Out:
# Station ID
# 151    2
# 167    2
# 461    2
# 55     1
# 147    1
#       ..
# 313    1
# 511    1
# 197    1
# 376    1
# 348    1
# Name: count, Length: 493, dtype: int64

# %%
#151, 167, and 461. Let's see what's going on with those
mta_data[mta_data['Station ID'] ==151]
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division                Line  \
# 231          A12         151         151      IND  8th Av - Fulton St
# 343          D13         151         151      IND           Concourse
#
#     Stop Name Borough    CBD Daytime Routes Structure  GTFS Latitude  \
# 231    145 St       M  False            A C    Subway      40.824783
# 343    145 St       M  False            B D    Subway      40.824783
#
#      GTFS Longitude North Direction Label South Direction Label  ADA  \
# 231      -73.944216                Uptown              Downtown    0
# 343      -73.944216                Uptown              Downtown    0
#
#      ADA Northbound  ADA Southbound ADA Notes                  Georeference
# 231               0               0       NaN  POINT (-73.944216 40.824783)
# 343               0               0       NaN  POINT (-73.944216 40.824783)

# %%
mta_data[mta_data['Station ID'] ==167]
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division                Line  \
# 218          A32         167         167      IND  8th Av - Fulton St
# 321          D20         167         167      IND     6th Av - Culver
#
#           Stop Name Borough   CBD Daytime Routes Structure  GTFS Latitude  \
# 218  W 4 St-Wash Sq       M  True          A C E    Subway      40.732338
# 321  W 4 St-Wash Sq       M  True        B D F M    Subway      40.732338
#
#      GTFS Longitude North Direction Label South Direction Label  ADA  \
# 218      -74.000495                Uptown              Downtown    1
# 321      -74.000495                Uptown              Downtown    1
#
#      ADA Northbound  ADA Southbound ADA Notes                  Georeference
# 218               1               1       NaN  POINT (-74.000495 40.732338)
# 321               1               1       NaN  POINT (-74.000495 40.732338)

# %%
mta_data[mta_data['Station ID'] ==461]
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division      Line         Stop Name  \
# 361          R09         461         461      BMT   Astoria  Queensboro Plaza
# 483          718         461         461      IRT  Flushing  Queensboro Plaza
#
#     Borough    CBD Daytime Routes Structure  GTFS Latitude  GTFS Longitude  \
# 361       Q  False            N W  Elevated      40.750582      -73.940202
# 483       Q  False              7  Elevated      40.750582      -73.940202
#
#     North Direction Label South Direction Label  ADA  ADA Northbound  \
# 361               Astoria             Manhattan    1               1
# 483              Outbound             Manhattan    1               1
#
#      ADA Southbound ADA Notes                  Georeference
# 361               1       NaN  POINT (-73.940202 40.750582)
# 483               1       NaN  POINT (-73.940202 40.750582)

# %%
#Ok, these appear to be different train platforms that for some reason share the same Station ID. But for this analysis we'll count them as distinct stations. 
#So the total station count for this analysis will be 475 intead of the MTA's official count of 472 stations.

# %%
#Moving on, let's get the SIR stations out the dataset for good. 
mta_stations = mta_data[mta_data.Division !='SIR']
mta_stations.shape
# Out:
# (475, 19)

# %%
#Perfect
#Now, to find how many are accessible. The ADA column looks like it's gonna be a boolean but let's find out. 

mta_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 495
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GTFS Stop ID           475 non-null    object
#  1   Station ID             475 non-null    int64
#  2   Complex ID             475 non-null    int64
#  3   Division               475 non-null    object
#  4   Line                   475 non-null    object
#  5   Stop Name              475 non-null    object
#  6   Borough                475 non-null    object
#  7   CBD                    475 non-null    bool
#  8   Daytime Routes         475 non-null    object
#  9   Structure              475 non-null    object
#  10  GTFS Latitude          475 non-null    float64
#  11  GTFS Longitude         475 non-null    float64
#  12  North Direction Label  475 non-null    object
#  13  South Direction Label  475 non-null    object
#  14  ADA                    475 non-null    int64
#  15  ADA Northbound         475 non-null    int64
#  16  ADA Southbound         475 non-null    int64
#  17  ADA Notes              9 non-null      object
#  18  Georeference           475 non-null    object
# dtypes: bool(1), float64(2), int64(5), object(11)
# memory usage: 71.0+ KB

# %%
#Not a boolean, just an integer. Let's look at the values for that

mta_stations.ADA.value_counts()
# Out:
# ADA
# 0    320
# 1    146
# 2      9
# Name: count, dtype: int64

# %%
#Ok, so the 0 and 1 do appear to represent True and False like a boolean...but what is 2? 
mta_stations[mta_stations.ADA == 2]
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division                 Line  \
# 11           233         336         336      IRT          Eastern Pky
# 98           633         404         404      IRT         Lexington Av
# 129          R15          10          10      BMT  Broadway - Brighton
# 148          G16         269         269      IND          Queens Blvd
# 198          L20         130         130      BMT             Canarsie
# 224          A25         162         162      IND   8th Av - Fulton St
# 240          423         415         620      IRT          Eastern Pky
# 391          F09         274         606      IND          Queens Blvd
# 438          626         397         397      IRT         Lexington Av
#
#           Stop Name Borough    CBD Daytime Routes Structure  GTFS Latitude  \
# 11          Hoyt St      Bk  False            2 3    Subway      40.690545
# 98            28 St       M   True              6    Subway      40.743070
# 129           49 St       M   True          N R W    Subway      40.759901
# 148   Northern Blvd       Q  False            M R    Subway      40.752885
# 198       Wilson Av      Bk  False              L    Subway      40.688764
# 224           50 St       M   True            C E    Subway      40.762456
# 240    Borough Hall      Bk  False            4 5    Subway      40.692404
# 391  Court Sq-23 St       Q  False            E M    Subway      40.747846
# 438           86 St       M  False          4 5 6    Subway      40.779492
#
#      GTFS Longitude North Direction Label South Direction Label  ADA  \
# 11       -73.985065             Manhattan              Outbound    2
# 98       -73.984264                Uptown              Downtown    2
# 129      -73.984139                Uptown              Downtown    2
# 148      -73.906006              Outbound             Manhattan    2
# 198      -73.904046             Manhattan              Outbound    2
# 224      -73.985984                Uptown              Downtown    2
# 240      -73.990151             Manhattan              Outbound    2
# 391      -73.946000              Outbound             Manhattan    2
# 438      -73.955589                Uptown              Downtown    2
#
#      ADA Northbound  ADA Southbound             ADA Notes  \
# 11                0               1         Outbound only
# 98                0               1         Downtown only
# 129               1               0           Uptown only
# 148               1               0         Outbound only
# 198               1               0  Manhattan-bound only
# 224               0               1         Downtown only
# 240               1               0  Manhattan-bound only
# 391               1               0  Manhattan-bound only
# 438               1               0     Uptown local only
#
#                      Georeference
# 11   POINT (-73.985065 40.690545)
# 98    POINT (-73.984264 40.74307)
# 129  POINT (-73.984139 40.759901)
# 148  POINT (-73.906006 40.752885)
# 198  POINT (-73.904046 40.688764)
# 224  POINT (-73.985984 40.762456)
# 240  POINT (-73.990151 40.692404)
# 391     POINT (-73.946 40.747846)
# 438  POINT (-73.955589 40.779492)

# %%
#Aha, looking at the ADA notes column, it looks like 2 means that the station is accessible but only in one direction. 
#I'll make an executive decsion to include those as accessible for this analysis and explain that in the methodology

# %%
#Moving on, let's find out what percentage of stations are accessible

ada_stations = mta_stations[mta_stations.ADA == 1] + mta_stations[mta_stations.ADA == 2]
len(ada_stations)
# Out:
# 155

# %%
#Now, just a little easy math to get a percent
percent_ada = len(ada_stations)/len(mta_stations) *100
percent_ada
# Out:
# 32.631578947368425

# %%
mta_stations[mta_stations.ADA == 1]
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division              Line  \
# 0            127         317         611      IRT    Broadway - 7Av
# 2            S01         139         627      BMT  Franklin Shuttle
# 4            M01         108         108      BMT         Myrtle Av
# 5            726         471         471      IRT          Flushing
# 7            615         373         373      IRT            Pelham
# ..           ...         ...         ...      ...               ...
# 485          M12          98          98      BMT           Jamaica
# 489          D07         215         215      IND         Concourse
# 490          L08         120         120      BMT          Canarsie
# 491          B06         222         222      IND           63rd St
# 492          J15          83          83      BMT           Jamaica
#
#                           Stop Name Borough    CBD Daytime Routes Structure  \
# 0                    Times Sq-42 St       M   True          1 2 3    Subway
# 2                       Franklin Av      Bk  False              S  Elevated
# 4    Middle Village-Metropolitan Av       Q  False              M  Elevated
# 5                34 St-Hudson Yards       M   True              7    Subway
# 7                          E 149 St      Bx  False              6    Subway
# ..                              ...     ...    ...            ...       ...
# 485                     Flushing Av      Bk  False            M J  Elevated
# 489                      Tremont Av      Bx  False            B D    Subway
# 490                      Bedford Av      Bk  False              L    Subway
# 491                Roosevelt Island       M  False              F    Subway
# 492                  Woodhaven Blvd       Q  False            J Z  Elevated
#
#      GTFS Latitude  GTFS Longitude North Direction Label  \
# 0        40.755290      -73.987495                Uptown
# 2        40.680596      -73.955827             Last Stop
# 4        40.711396      -73.889601               Inbound
# 5        40.755882      -74.001910             Last Stop
# 7        40.812118      -73.904098            Northbound
# ..             ...             ...                   ...
# 485      40.700260      -73.941126              Outbound
# 489      40.850410      -73.905227            Northbound
# 490      40.717304      -73.956872             Manhattan
# 491      40.759145      -73.953260                Queens
# 492      40.693879      -73.851576               Jamaica
#
#     South Direction Label  ADA  ADA Northbound  ADA Southbound ADA Notes  \
# 0                Downtown    1               1               1       NaN
# 2           Prospect Park    1               1               1       NaN
# 4               Last Stop    1               1               1       NaN
# 5                  Queens    1               1               1       NaN
# 7               Manhattan    1               1               1       NaN
# ..                    ...  ...             ...             ...       ...
# 485             Manhattan    1               1               1       NaN
# 489             Manhattan    1               1               1       NaN
# 490              Outbound    1               1               1       NaN
# 491              Downtown    1               1               1       NaN
# 492             Manhattan    1               1               1       NaN
#
#                      Georeference
# 0     POINT (-73.987495 40.75529)
# 2    POINT (-73.955827 40.680596)
# 4    POINT (-73.889601 40.711396)
# 5     POINT (-74.00191 40.755882)
# 7    POINT (-73.904098 40.812118)
# ..                            ...
# 485   POINT (-73.941126 40.70026)
# 489   POINT (-73.905227 40.85041)
# 490  POINT (-73.956872 40.717304)
# 491   POINT (-73.95326 40.759145)
# 492  POINT (-73.851576 40.693879)
#
# [146 rows x 19 columns]

# %%
mta_stations[mta_stations.ADA == 2].shape
# Out:
# (9, 19)

# %%
ada_stations = mta_stations[mta_stations.ADA >= 1]

# %%
ada_stations
# Out:
#     GTFS Stop ID  Station ID  Complex ID Division              Line  \
# 0            127         317         611      IRT    Broadway - 7Av
# 2            S01         139         627      BMT  Franklin Shuttle
# 4            M01         108         108      BMT         Myrtle Av
# 5            726         471         471      IRT          Flushing
# 7            615         373         373      IRT            Pelham
# ..           ...         ...         ...      ...               ...
# 485          M12          98          98      BMT           Jamaica
# 489          D07         215         215      IND         Concourse
# 490          L08         120         120      BMT          Canarsie
# 491          B06         222         222      IND           63rd St
# 492          J15          83          83      BMT           Jamaica
#
#                           Stop Name Borough    CBD Daytime Routes Structure  \
# 0                    Times Sq-42 St       M   True          1 2 3    Subway
# 2                       Franklin Av      Bk  False              S  Elevated
# 4    Middle Village-Metropolitan Av       Q  False              M  Elevated
# 5                34 St-Hudson Yards       M   True              7    Subway
# 7                          E 149 St      Bx  False              6    Subway
# ..                              ...     ...    ...            ...       ...
# 485                     Flushing Av      Bk  False            M J  Elevated
# 489                      Tremont Av      Bx  False            B D    Subway
# 490                      Bedford Av      Bk  False              L    Subway
# 491                Roosevelt Island       M  False              F    Subway
# 492                  Woodhaven Blvd       Q  False            J Z  Elevated
#
#      GTFS Latitude  GTFS Longitude North Direction Label  \
# 0        40.755290      -73.987495                Uptown
# 2        40.680596      -73.955827             Last Stop
# 4        40.711396      -73.889601               Inbound
# 5        40.755882      -74.001910             Last Stop
# 7        40.812118      -73.904098            Northbound
# ..             ...             ...                   ...
# 485      40.700260      -73.941126              Outbound
# 489      40.850410      -73.905227            Northbound
# 490      40.717304      -73.956872             Manhattan
# 491      40.759145      -73.953260                Queens
# 492      40.693879      -73.851576               Jamaica
#
#     South Direction Label  ADA  ADA Northbound  ADA Southbound ADA Notes  \
# 0                Downtown    1               1               1       NaN
# 2           Prospect Park    1               1               1       NaN
# 4               Last Stop    1               1               1       NaN
# 5                  Queens    1               1               1       NaN
# 7               Manhattan    1               1               1       NaN
# ..                    ...  ...             ...             ...       ...
# 485             Manhattan    1               1               1       NaN
# 489             Manhattan    1               1               1       NaN
# 490              Outbound    1               1               1       NaN
# 491              Downtown    1               1               1       NaN
# 492             Manhattan    1               1               1       NaN
#
#                      Georeference
# 0     POINT (-73.987495 40.75529)
# 2    POINT (-73.955827 40.680596)
# 4    POINT (-73.889601 40.711396)
# 5     POINT (-74.00191 40.755882)
# 7    POINT (-73.904098 40.812118)
# ..                            ...
# 485   POINT (-73.941126 40.70026)
# 489   POINT (-73.905227 40.85041)
# 490  POINT (-73.956872 40.717304)
# 491   POINT (-73.95326 40.759145)
# 492  POINT (-73.851576 40.693879)
#
# [155 rows x 19 columns]

# %%
ada_stations.to_csv('ada_stations.csv')

# %%
#look at the distances between accessible stations
distances = pd.read_csv('distances.csv')
distances.head()
# Out:
#                         InputID                      TargetID     Distance
# 0  POINT (-73.955827 40.680596)   POINT (-73.956848 40.68138)   122.596691
# 1  POINT (-73.889601 40.711396)  POINT (-73.911586 40.699814)  2259.660798
# 2  POINT (-73.904098 40.812118)  POINT (-73.917757 40.816109)  1234.711044
# 3  POINT (-73.985065 40.690545)   POINT (-73.985942 40.69218)   196.113422
# 4  POINT (-73.842952 40.839892)  POINT (-73.828121 40.852462)  1874.254365

# %%
#average distsance? 
distances['Distance'].mean()
# Out:
# np.float64(1066.2041507226438)

# %%
#that's in meters, so the average distance is actually more than a kilometer
distances['Distance'].mean()/1000
# Out:
# np.float64(1.0662041507226439)

# %%
#look at the distances between all stations
all_distances = pd.read_csv('all_distance.csv')
all_distances.head()
# Out:
#                         InputID                      TargetID     Distance
# 0   POINT (-74.178217 40.54046)   POINT (-74.16457 40.544601)  1244.188824
# 1  POINT (-73.955827 40.680596)   POINT (-73.956848 40.68138)   122.596691
# 2  POINT (-73.902447 40.663515)  POINT (-73.900571 40.664038)   168.934045
# 3  POINT (-73.889601 40.711396)  POINT (-73.895877 40.706186)   784.859326
# 4  POINT (-73.912549 40.744149)  POINT (-73.918435 40.743132)   509.800374

# %%
all_distances['Distance'].mean()/1000
# Out:
# np.float64(0.5410217059049867)

# %%
#ok, almost twice as far
full_stations_distances = pd.read_csv('all_stations_distances.csv')
full_stations_distances.head()
# Out:
#                         InputID                      TargetID     Distance
# 0   POINT (-73.987495 40.75529)  POINT (-73.987691 40.755477)    26.555242
# 1   POINT (-74.178217 40.54046)   POINT (-74.16457 40.544601)  1244.188824
# 2  POINT (-73.955827 40.680596)   POINT (-73.956848 40.68138)   122.596691
# 3  POINT (-73.902447 40.663515)  POINT (-73.900571 40.664038)   168.934045
# 4  POINT (-73.889601 40.711396)  POINT (-73.895877 40.706186)   784.859326

# %%
#This is the average distances between all stations, including the CBD
full_stations_distances['Distance'].mean()/1000
# Out:
# np.float64(0.4727719395611448)

# %%
full_ada_stations_distances = pd.read_csv('all_ada_stations_distances.csv')
full_ada_stations_distances.head()
# Out:
#                         InputID                      TargetID     Distance
# 0   POINT (-73.987495 40.75529)  POINT (-73.987691 40.755477)    26.555242
# 1  POINT (-73.955827 40.680596)   POINT (-73.956848 40.68138)   122.596691
# 2  POINT (-73.889601 40.711396)  POINT (-73.911586 40.699814)  2259.660798
# 3   POINT (-74.00191 40.755882)  POINT (-73.993391 40.752287)   822.752385
# 4  POINT (-73.904098 40.812118)  POINT (-73.917757 40.816109)  1234.711044

# %%
#Distances between all ADA stations, including the CBD
full_ada_stations_distances['Distance'].mean()/1000
# Out:
# np.float64(0.8026468022479628)
